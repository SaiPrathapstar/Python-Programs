# %% [markdown]
# **PANDAS**

# %%
import numpy as np
import matplotlib.pyplot as plt 
import pandas as pd

# %%
#PANDAS SERIES
#PANDAS DATAFRAME

# %%
#create a series using numpy array
data = np.array(['abc','bca','cda','deee','eeee','ffff'])
series1 = pd.Series(data)
series1
# Out:
# 0     abc
# 1     bca
# 2     cda
# 3    deee
# 4    eeee
# 5    ffff
# dtype: object

# %%
type(series1)
# Out:
# pandas.core.series.Series

# %%
#READ A TXT FILE AND CREATE A DATAFRAME

# %%
df = pd.read_csv('/content/fruit_data_with_colors.txt',sep ='\t')
df

# %%
df.head()   #displays the first 5 rows of the dataframe

# %%
df.head(10)  #displays the first 10 rows of the dataframe

# %%
df.tail()   #display the last 5 rows of the dataframe

# %%
df.tail(10)   #display the last 10 rows of the dataframe

# %%
df.info() #gives complete information about the dataframe
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 59 entries, 0 to 58
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   fruit_label    59 non-null     int64
#  1   fruit_name     59 non-null     object
#  2   fruit_subtype  59 non-null     object
#  3   mass           59 non-null     int64
#  4   width          59 non-null     float64
#  5   height         59 non-null     float64
#  6   color_score    59 non-null     float64
# dtypes: float64(3), int64(2), object(2)
# memory usage: 3.4+ KB

# %%
# NaN - Not a number (null value)
df.isnull().sum()   #missing / empty / null values in the dataset 
#null values are supposed to be removed from the dataset for ml algorithms
# Out:
# fruit_label      0
# fruit_name       0
# fruit_subtype    0
# mass             0
# width            0
# height           0
# color_score      0
# dtype: int64

# %%
df[20:25]   #slicing

# %%
df.iloc[20:25,0:3]   #slicing  #index based location 
#       rows,columns

# %%
df.head()
# Out:
#    fruit_label fruit_name fruit_subtype  mass  width  height  color_score
# 0            1      apple  granny_smith   192    8.4     7.3         0.55
# 1            1      apple  granny_smith   180    8.0     6.8         0.59
# 2            1      apple  granny_smith   176    7.4     7.2         0.60
# 3            2   mandarin      mandarin    86    6.2     4.7         0.80
# 4            2   mandarin      mandarin    84    6.0     4.6         0.79

# %%
df['fruit_name'][0]
# Out:
# 'apple'

# %%
df.iloc[:,-1] #negative indexing #it creates a series for one column

# %%
#to convert series to numpy array add .values
df.iloc[:,-1].values

# %%
xyz = df.fruit_subtype
xyz

# %%
xyz = df.fruit_subtype.unique() # unique values from the dataframe
xyz
# Out:
# array(['granny_smith', 'mandarin', 'braeburn', 'golden_delicious',
#        'cripps_pink', 'spanish_jumbo', 'selected_seconds', 'turkey_navel',
#        'spanish_belsan', 'unknown'], dtype=object)

# %%
#plot visuals using matplotlib 
#create a series for one column
fname = df.fruit_name
fname

# %%
fname = df.fruit_name.unique() # unique values from the dataframe
fname
# Out:
# array(['apple', 'mandarin', 'orange', 'lemon'], dtype=object)

# %%
fname1 = df.groupby('fruit_name',sort = False).size() #by default sort is true which is not accepted by matplotlib while plotting
# so we make sort = False to get the correct output in the graph(matplotlib takes numbers to plot and not the text data)
fname1
# Out:
# fruit_name
# apple       19
# mandarin     5
# orange      19
# lemon       16
# dtype: int64

# %%
import matplotlib.pyplot as plt 
plt.bar(fname,fname1)

# %%
#to get the numbers in descending order we use value_counts()
df['fruit_name'].value_counts(ascending=True)
df['fruit_name'].value_counts(ascending=False)
df['fruit_name'].value_counts() #by default it is descending order
# Out:
# orange      19
# apple       19
# lemon       16
# mandarin     5
# Name: fruit_name, dtype: int64

# %%
df.head()
# Out:
#    fruit_label fruit_name fruit_subtype  mass  width  height  color_score
# 0            1      apple  granny_smith   192    8.4     7.3         0.55
# 1            1      apple  granny_smith   180    8.0     6.8         0.59
# 2            1      apple  granny_smith   176    7.4     7.2         0.60
# 3            2   mandarin      mandarin    86    6.2     4.7         0.80
# 4            2   mandarin      mandarin    84    6.0     4.6         0.79

# %%
# create two series for height column and width column 
# create a scatter plot for these two series

# %%
height = df.height
height

# %%
width = df.width
width

# %%
plt.scatter(height,width)
plt.show()

# %%
df.shape   #rows , columns
# Out:
# (59, 7)

# %%
df.size   #total number of values  (rows * columns )
# Out:
# 413

# %%
df.columns  #gives column names list
# Out:
# Index(['fruit_label', 'fruit_name', 'fruit_subtype', 'mass', 'width', 'height',
#        'color_score'],
#       dtype='object')

# %%
df.describe()   #summary statistics of the dataframe of numerical columns only
# Out:
#        fruit_label        mass      width     height  color_score
# count    59.000000   59.000000  59.000000  59.000000    59.000000
# mean      2.542373  163.118644   7.105085   7.693220     0.762881
# std       1.208048   55.018832   0.816938   1.361017     0.076857
# min       1.000000   76.000000   5.800000   4.000000     0.550000
# 25%       1.000000  140.000000   6.600000   7.200000     0.720000
# 50%       3.000000  158.000000   7.200000   7.600000     0.750000
# 75%       4.000000  177.000000   7.500000   8.200000     0.810000
# max       4.000000  362.000000   9.600000  10.500000     0.930000

# %%
#deserialization 
import pickle
model = pickle.load(open('linear.pkl','rb')) #loads the model # read byte

# %%
model.predict([[2.0]])
# Out:
# array([44692.12484158])

# %%
model.coef_
# Out:
# array([9449.96232146])

# %%
model.intercept_
# Out:
# 25792.200198668696
